# %% [markdown]
# # Übungsblatt 4

# %%
from math import e, sin

# %% [markdown]
# ## Aufgabe 4

# %%
x: float = 0.000001

# %%
((e**x)-1)/x
# Out:
# 1.0000004999621837

# %% [markdown]
# => 1

# %%
sin(3*x)/x
# Out:
# 2.9999999999955005

# %% [markdown]
# => 3

# %%
sin(1/x)
# Out:
# -0.34999350217129294

# %%
x = -9999

(e**x)/x**2
# Out:
# 0.0

# %%
x = 99

(e**x)/x**2
# Out:
# 1.0089817691405871e+39

# %% [markdown]
# => inf
